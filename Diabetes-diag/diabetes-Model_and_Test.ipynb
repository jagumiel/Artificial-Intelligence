# %%
import pandas as pd
diabetes_train = pd.read_csv('train/pima-indians-diabetes.csv')
diabetes_test = pd.read_csv('test/pima-indians-diabetes.csv')
diabetes_train.head()
# Out:
#    Number Pregnant  Glucose Concentration  Blood Pressure  Triceps  Insulin  \
# 0                6                    148              72       35        0
# 1                1                     85              66       29        0
# 2                8                    183              64        0        0
# 3                1                     89              66       23       94
# 4                0                    137              40       35      168
#
#     BMI  Pedigree  Age  Class Group
# 0  33.6     0.627   50      1     D
# 1  26.6     0.351   31      0     E
# 2  23.3     0.672   32      1     B
# 3  28.1     0.167   21      0     C
# 4  43.1     2.288   33      1     E

# %%
diabetes_train.columns
cols_to_norm = ['Number Pregnant', 'Glucose Concentration', 'Blood Pressure', 'Triceps', 'Insulin' , 'BMI', 'Pedigree']
diabetes_train[cols_to_norm] = diabetes_train[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min()))
diabetes_test.columns
diabetes_test[cols_to_norm] = diabetes_train[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min()))
diabetes_train.head()
#diabetes_test.head()
# Out:
#    Number Pregnant  Glucose Concentration  Blood Pressure   Triceps   Insulin  \
# 0         0.352941               0.747475        0.590164  0.353535  0.000000
# 1         0.058824               0.429293        0.540984  0.292929  0.000000
# 2         0.470588               0.924242        0.524590  0.000000  0.000000
# 3         0.058824               0.449495        0.540984  0.232323  0.111111
# 4         0.000000               0.691919        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     D
# 1  0.396423  0.116567   31      0     E
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     C
# 4  0.642325  0.943638   33      1     E

# %%
import tensorflow as tf
num_preg = tf.feature_column.numeric_column('Number Pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose Concentration')
dias_press = tf.feature_column.numeric_column('Blood Pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %%
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A','B','C','D','E'])
import matplotlib.pyplot as plt
# %matplotlib inline
diabetes_train['Age'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
age_buckets = tf.feature_column.bucketized_column(age,boundaries=[20,30,40,50,60,70,80])
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep,insulin,bmi,diabetes_pedigree ,assigned_group, age_buckets]

# %%
x_data_train = diabetes_train.drop('Class',axis=1)
labels_train = diabetes_train['Class']
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_data_train,labels_train,test_size=0.33,random_state=101)

# %%
input_func = tf.compat.v1.estimator.inputs.pandas_input_fn(x=x_train,y=y_train,
                                                batch_size=10,
                                                num_epochs=1000,
                                                shuffle=True)
model = tf.estimator.LinearClassifier(feature_columns=feat_cols,n_classes=2)
model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\jagumiel\AppData\Local\Temp\tmp9nr2npm1
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\jagumiel\\AppData\\Local\\Temp\\tmp9nr2npm1', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:From c:\users\jagumiel\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\training\training_util.py:235: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From c:\users\jagumiel\appdata\local\programs\python\python38\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_queue_runner.py:60: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From c:\users\jagumiel\appdata\local\programs\python\python38\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_functions.py:491: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:From c:\users\jagumiel\appdata\local\programs\python\python38\lib\site-packages\tensorflow_estimator\python\estimator\canned\linear.py:1471: Layer.add_variable (from tensorflow.python.keras.engine.base_layer_v1) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From c:\users\jagumiel\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\keras\optimizer_v2\ftrl.py:111: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From c:\users\jagumiel\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\training\monitored_session.py:906: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\jagumiel\AppData\Local\Temp\tmp9nr2npm1\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 0.6931472, step = 0
# INFO:tensorflow:global_step/sec: 473.593
# INFO:tensorflow:loss = 0.48521623, step = 100 (0.212 sec)
# INFO:tensorflow:global_step/sec: 796.24
# INFO:tensorflow:loss = 0.52179193, step = 200 (0.129 sec)
# INFO:tensorflow:global_step/sec: 734.441
# INFO:tensorflow:loss = 0.56603956, step = 300 (0.133 sec)
# INFO:tensorflow:global_step/sec: 809.132
# INFO:tensorflow:loss = 0.61351174, step = 400 (0.124 sec)
# INFO:tensorflow:global_step/sec: 744.038
# INFO:tensorflow:loss = 0.72819436, step = 500 (0.133 sec)
# INFO:tensorflow:global_step/sec: 829.278
# INFO:tensorflow:loss = 0.31347293, step = 600 (0.121 sec)
# INFO:tensorflow:global_step/sec: 777.649
# INFO:tensorflow:loss = 0.3830408, step = 700 (0.130 sec)
# INFO:tensorflow:global_step/sec: 819.083
# INFO:tensorflow:loss = 0.30147427, step = 800 (0.122 sec)
# INFO:tensorflow:global_step/sec: 783.748
# INFO:tensorflow:loss = 0.8724451, step = 900 (0.128 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1000...
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\jagumiel\AppData\Local\Temp\tmp9nr2npm1\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1000...
# INFO:tensorflow:Loss for final step: 0.57519823.

# %%
pred_input_func = tf.compat.v1.estimator.inputs.pandas_input_fn(x=x_test, batch_size=10, num_epochs=1, shuffle=False)
predictions = model.predict(pred_input_func)
list(predictions)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\jagumiel\AppData\Local\Temp\tmp9nr2npm1\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'logits': array([0.28316426], dtype=float32),
#   'logistic': array([0.5703218], dtype=float32),
#   'probabilities': array([0.42967817, 0.5703218 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2863398], dtype=float32),
#   'logistic': array([0.21647298], dtype=float32),
#   'probabilities': array([0.783527, 0.216473], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2668774], dtype=float32),
#   'logistic': array([0.21979225], dtype=float32),
#   'probabilities': array([0.78020775, 0.21979226], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.22153747], dtype=float32),
#   'logistic': array([0.44484106], dtype=float32),
#   'probabilities': array([0.555159  , 0.44484103], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.43837106], dtype=float32),
#   'logistic': array([0.39212918], dtype=float32),
#   'probabilities': array([0.6078708, 0.3921292], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3486103], dtype=float32),
#   'logistic': array([0.20609766], dtype=float32),
#   'probabilities': array([0.79390234, 0.20609768], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.6465429], dtype=float32),
#   'logistic': array([0.656231], dtype=float32),
#   'probabilities': array([0.343769, 0.656231], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6394671], dtype=float32),
#   'logistic': array([0.16253757], dtype=float32),
#   'probabilities': array([0.8374624 , 0.16253759], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2557179], dtype=float32),
#   'logistic': array([0.2217119], dtype=float32),
#   'probabilities': array([0.77828807, 0.22171192], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.872781], dtype=float32),
#   'logistic': array([0.13322026], dtype=float32),
#   'probabilities': array([0.8667798 , 0.13322027], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8099278], dtype=float32),
#   'logistic': array([0.14064685], dtype=float32),
#   'probabilities': array([0.8593531 , 0.14064685], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.88245755], dtype=float32),
#   'logistic': array([0.2926688], dtype=float32),
#   'probabilities': array([0.70733124, 0.29266876], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.1189928], dtype=float32),
#   'logistic': array([0.10726443], dtype=float32),
#   'probabilities': array([0.89273554, 0.10726448], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4808953], dtype=float32),
#   'logistic': array([0.18529224], dtype=float32),
#   'probabilities': array([0.8147078 , 0.18529224], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.41951275], dtype=float32),
#   'logistic': array([0.6033666], dtype=float32),
#   'probabilities': array([0.39663336, 0.6033667 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.2910843], dtype=float32),
#   'logistic': array([0.42773843], dtype=float32),
#   'probabilities': array([0.5722616 , 0.42773846], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.539767], dtype=float32),
#   'logistic': array([0.1765692], dtype=float32),
#   'probabilities': array([0.82343084, 0.17656913], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.0179019], dtype=float32),
#   'logistic': array([0.50447536], dtype=float32),
#   'probabilities': array([0.49552464, 0.50447536], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.182176], dtype=float32),
#   'logistic': array([0.10136253], dtype=float32),
#   'probabilities': array([0.8986375 , 0.10136254], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.11875057], dtype=float32),
#   'logistic': array([0.5296528], dtype=float32),
#   'probabilities': array([0.47034717, 0.5296528 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.63370025], dtype=float32),
#   'logistic': array([0.653328], dtype=float32),
#   'probabilities': array([0.346672, 0.653328], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6862226], dtype=float32),
#   'logistic': array([0.15627325], dtype=float32),
#   'probabilities': array([0.84372675, 0.15627326], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6465103], dtype=float32),
#   'logistic': array([0.34377638], dtype=float32),
#   'probabilities': array([0.65622365, 0.34377638], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.637025], dtype=float32),
#   'logistic': array([0.34591937], dtype=float32),
#   'probabilities': array([0.6540806, 0.3459193], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4506676], dtype=float32),
#   'logistic': array([0.18989882], dtype=float32),
#   'probabilities': array([0.81010115, 0.18989885], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.03596711], dtype=float32),
#   'logistic': array([0.5089908], dtype=float32),
#   'probabilities': array([0.49100915, 0.50899076], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1087265], dtype=float32),
#   'logistic': array([0.24810839], dtype=float32),
#   'probabilities': array([0.7518916 , 0.24810837], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.36098874], dtype=float32),
#   'logistic': array([0.5892798], dtype=float32),
#   'probabilities': array([0.4107202, 0.5892797], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2548157], dtype=float32),
#   'logistic': array([0.22186762], dtype=float32),
#   'probabilities': array([0.7781324 , 0.22186764], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.15752405], dtype=float32),
#   'logistic': array([0.4607002], dtype=float32),
#   'probabilities': array([0.5392998, 0.4607002], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.73234475], dtype=float32),
#   'logistic': array([0.32468042], dtype=float32),
#   'probabilities': array([0.6753196 , 0.32468042], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.55999744], dtype=float32),
#   'logistic': array([0.36354804], dtype=float32),
#   'probabilities': array([0.63645196, 0.36354804], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1392438], dtype=float32),
#   'logistic': array([0.24245921], dtype=float32),
#   'probabilities': array([0.75754076, 0.24245921], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5755705], dtype=float32),
#   'logistic': array([0.17142373], dtype=float32),
#   'probabilities': array([0.82857627, 0.17142372], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.08815682], dtype=float32),
#   'logistic': array([0.5220249], dtype=float32),
#   'probabilities': array([0.47797504, 0.5220249 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9189879], dtype=float32),
#   'logistic': array([0.12797451], dtype=float32),
#   'probabilities': array([0.8720255 , 0.12797448], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.4714049], dtype=float32),
#   'logistic': array([0.6157162], dtype=float32),
#   'probabilities': array([0.38428378, 0.6157162 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9163852], dtype=float32),
#   'logistic': array([0.1282652], dtype=float32),
#   'probabilities': array([0.8717348 , 0.12826522], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.07199776], dtype=float32),
#   'logistic': array([0.51799166], dtype=float32),
#   'probabilities': array([0.48200834, 0.51799166], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6633359], dtype=float32),
#   'logistic': array([0.15931469], dtype=float32),
#   'probabilities': array([0.84068525, 0.15931469], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.99201566], dtype=float32),
#   'logistic': array([0.27051413], dtype=float32),
#   'probabilities': array([0.72948587, 0.27051413], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.15364265], dtype=float32),
#   'logistic': array([0.46166474], dtype=float32),
#   'probabilities': array([0.53833526, 0.4616647 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5035669], dtype=float32),
#   'logistic': array([0.18189415], dtype=float32),
#   'probabilities': array([0.8181059 , 0.18189414], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0397681], dtype=float32),
#   'logistic': array([0.26119474], dtype=float32),
#   'probabilities': array([0.7388053 , 0.26119477], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.1483893], dtype=float32),
#   'logistic': array([0.10448185], dtype=float32),
#   'probabilities': array([0.8955182 , 0.10448183], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7647274], dtype=float32),
#   'logistic': array([0.3176208], dtype=float32),
#   'probabilities': array([0.68237925, 0.31762078], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7828777], dtype=float32),
#   'logistic': array([0.31370002], dtype=float32),
#   'probabilities': array([0.68630004, 0.31370005], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.24981773], dtype=float32),
#   'logistic': array([0.43786836], dtype=float32),
#   'probabilities': array([0.56213164, 0.4378684 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.19918215], dtype=float32),
#   'logistic': array([0.54963154], dtype=float32),
#   'probabilities': array([0.45036846, 0.5496316 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.2439746], dtype=float32),
#   'logistic': array([0.7762551], dtype=float32),
#   'probabilities': array([0.2237449, 0.7762551], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6132526], dtype=float32),
#   'logistic': array([0.16613749], dtype=float32),
#   'probabilities': array([0.8338625 , 0.16613752], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.73097557], dtype=float32),
#   'logistic': array([0.32498068], dtype=float32),
#   'probabilities': array([0.6750193 , 0.32498068], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.613812], dtype=float32),
#   'logistic': array([0.16606003], dtype=float32),
#   'probabilities': array([0.83393997, 0.16606006], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5360339], dtype=float32),
#   'logistic': array([0.17711255], dtype=float32),
#   'probabilities': array([0.8228874 , 0.17711258], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.2372646], dtype=float32),
#   'logistic': array([0.09645364], dtype=float32),
#   'probabilities': array([0.90354633, 0.09645367], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.02357256], dtype=float32),
#   'logistic': array([0.5058929], dtype=float32),
#   'probabilities': array([0.49410713, 0.5058929 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4579262], dtype=float32),
#   'logistic': array([0.18878472], dtype=float32),
#   'probabilities': array([0.81121534, 0.18878473], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3861846], dtype=float32),
#   'logistic': array([0.20001757], dtype=float32),
#   'probabilities': array([0.7999824 , 0.20001757], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8832786], dtype=float32),
#   'logistic': array([0.13201272], dtype=float32),
#   'probabilities': array([0.8679872 , 0.13201272], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1417601], dtype=float32),
#   'logistic': array([0.24199736], dtype=float32),
#   'probabilities': array([0.7580027 , 0.24199736], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.9599346], dtype=float32),
#   'logistic': array([0.2768913], dtype=float32),
#   'probabilities': array([0.7231087, 0.2768913], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.6712369], dtype=float32),
#   'logistic': array([0.66178006], dtype=float32),
#   'probabilities': array([0.33821997, 0.6617801 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.358158], dtype=float32),
#   'logistic': array([0.41140556], dtype=float32),
#   'probabilities': array([0.58859444, 0.4114055 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9255025], dtype=float32),
#   'logistic': array([0.12724921], dtype=float32),
#   'probabilities': array([0.87275076, 0.12724921], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6178231], dtype=float32),
#   'logistic': array([0.16550532], dtype=float32),
#   'probabilities': array([0.8344947, 0.1655053], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.64061034], dtype=float32),
#   'logistic': array([0.34510857], dtype=float32),
#   'probabilities': array([0.65489143, 0.3451086 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.58347344], dtype=float32),
#   'logistic': array([0.35813376], dtype=float32),
#   'probabilities': array([0.64186627, 0.35813373], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0812194], dtype=float32),
#   'logistic': array([0.25327533], dtype=float32),
#   'probabilities': array([0.74672467, 0.2532753 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.32524025], dtype=float32),
#   'logistic': array([0.5806008], dtype=float32),
#   'probabilities': array([0.4193992 , 0.58060086], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3139701], dtype=float32),
#   'logistic': array([0.21182328], dtype=float32),
#   'probabilities': array([0.7881768 , 0.21182327], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.1439573], dtype=float32),
#   'logistic': array([0.24159452], dtype=float32),
#   'probabilities': array([0.75840545, 0.24159455], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.0318346], dtype=float32),
#   'logistic': array([0.507958], dtype=float32),
#   'probabilities': array([0.49204203, 0.507958  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.10963142], dtype=float32),
#   'logistic': array([0.5273804], dtype=float32),
#   'probabilities': array([0.47261953, 0.5273804 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.9803312], dtype=float32),
#   'logistic': array([0.27282608], dtype=float32),
#   'probabilities': array([0.7271739 , 0.27282608], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6408715], dtype=float32),
#   'logistic': array([0.16234651], dtype=float32),
#   'probabilities': array([0.8376535 , 0.16234651], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.847115], dtype=float32),
#   'logistic': array([0.13621196], dtype=float32),
#   'probabilities': array([0.863788  , 0.13621198], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.04475319], dtype=float32),
#   'logistic': array([0.48881358], dtype=float32),
#   'probabilities': array([0.5111864 , 0.48881355], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5133033], dtype=float32),
#   'logistic': array([0.18044975], dtype=float32),
#   'probabilities': array([0.8195502 , 0.18044975], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.05744624], dtype=float32),
#   'logistic': array([0.5143576], dtype=float32),
#   'probabilities': array([0.48564237, 0.5143576 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8550963], dtype=float32),
#   'logistic': array([0.29836488], dtype=float32),
#   'probabilities': array([0.7016351, 0.2983649], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6227136], dtype=float32),
#   'logistic': array([0.16483098], dtype=float32),
#   'probabilities': array([0.835169  , 0.16483098], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4852284], dtype=float32),
#   'logistic': array([0.184639], dtype=float32),
#   'probabilities': array([0.815361  , 0.18463899], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.60665244], dtype=float32),
#   'logistic': array([0.3528232], dtype=float32),
#   'probabilities': array([0.6471768, 0.3528232], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.01907122], dtype=float32),
#   'logistic': array([0.49523234], dtype=float32),
#   'probabilities': array([0.50476766, 0.49523234], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.54795134], dtype=float32),
#   'logistic': array([0.36633986], dtype=float32),
#   'probabilities': array([0.63366014, 0.36633983], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0390291], dtype=float32),
#   'logistic': array([0.11516562], dtype=float32),
#   'probabilities': array([0.8848344 , 0.11516564], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.0868258], dtype=float32),
#   'logistic': array([0.11038387], dtype=float32),
#   'probabilities': array([0.8896161 , 0.11038388], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.9829876], dtype=float32),
#   'logistic': array([0.2722994], dtype=float32),
#   'probabilities': array([0.7277006 , 0.27229938], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.22688472], dtype=float32),
#   'logistic': array([0.4435209], dtype=float32),
#   'probabilities': array([0.55647916, 0.4435209 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6843698], dtype=float32),
#   'logistic': array([0.3352867], dtype=float32),
#   'probabilities': array([0.6647133, 0.3352867], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.82495034], dtype=float32),
#   'logistic': array([0.30471388], dtype=float32),
#   'probabilities': array([0.69528615, 0.30471385], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7810758], dtype=float32),
#   'logistic': array([0.14417034], dtype=float32),
#   'probabilities': array([0.85582966, 0.14417034], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7311927], dtype=float32),
#   'logistic': array([0.32493308], dtype=float32),
#   'probabilities': array([0.67506695, 0.32493305], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.01496077], dtype=float32),
#   'logistic': array([0.50374013], dtype=float32),
#   'probabilities': array([0.49625987, 0.50374013], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7450671], dtype=float32),
#   'logistic': array([0.32189712], dtype=float32),
#   'probabilities': array([0.6781029 , 0.32189712], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.32785434], dtype=float32),
#   'logistic': array([0.4187628], dtype=float32),
#   'probabilities': array([0.5812372 , 0.41876274], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.2731681], dtype=float32),
#   'logistic': array([0.4321295], dtype=float32),
#   'probabilities': array([0.5678705, 0.4321295], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9161272], dtype=float32),
#   'logistic': array([0.12829402], dtype=float32),
#   'probabilities': array([0.871706  , 0.12829407], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.57857203], dtype=float32),
#   'logistic': array([0.6407387], dtype=float32),
#   'probabilities': array([0.3592612, 0.6407387], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6498419], dtype=float32),
#   'logistic': array([0.16113031], dtype=float32),
#   'probabilities': array([0.8388697 , 0.16113032], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7015755], dtype=float32),
#   'logistic': array([0.33146304], dtype=float32),
#   'probabilities': array([0.66853696, 0.33146298], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7676466], dtype=float32),
#   'logistic': array([0.14583522], dtype=float32),
#   'probabilities': array([0.8541648 , 0.14583525], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.6326916], dtype=float32),
#   'logistic': array([0.65309954], dtype=float32),
#   'probabilities': array([0.34690046, 0.65309954], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.679361], dtype=float32),
#   'logistic': array([0.66359603], dtype=float32),
#   'probabilities': array([0.33640394, 0.66359603], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.7169722], dtype=float32),
#   'logistic': array([0.3280601], dtype=float32),
#   'probabilities': array([0.6719399 , 0.32806006], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3980708], dtype=float32),
#   'logistic': array([0.19812244], dtype=float32),
#   'probabilities': array([0.80187756, 0.19812243], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.87468], dtype=float32),
#   'logistic': array([0.13300112], dtype=float32),
#   'probabilities': array([0.8669989 , 0.13300113], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.12960374], dtype=float32),
#   'logistic': array([0.53235567], dtype=float32),
#   'probabilities': array([0.46764436, 0.53235567], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.22263193], dtype=float32),
#   'logistic': array([0.5554292], dtype=float32),
#   'probabilities': array([0.4445708, 0.5554293], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9060338], dtype=float32),
#   'logistic': array([0.12942708], dtype=float32),
#   'probabilities': array([0.8705729 , 0.12942709], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.3317746], dtype=float32),
#   'logistic': array([0.41780892], dtype=float32),
#   'probabilities': array([0.5821911 , 0.41780892], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0834055], dtype=float32),
#   'logistic': array([0.2528621], dtype=float32),
#   'probabilities': array([0.7471379, 0.2528621], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.0783464], dtype=float32),
#   'logistic': array([0.7461809], dtype=float32),
#   'probabilities': array([0.2538191 , 0.74618095], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8720302], dtype=float32),
#   'logistic': array([0.29483205], dtype=float32),
#   'probabilities': array([0.705168  , 0.29483205], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.11829501], dtype=float32),
#   'logistic': array([0.47046068], dtype=float32),
#   'probabilities': array([0.5295393 , 0.47046068], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8286771], dtype=float32),
#   'logistic': array([0.30392486], dtype=float32),
#   'probabilities': array([0.6960752, 0.3039249], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.2549516], dtype=float32),
#   'logistic': array([0.5633949], dtype=float32),
#   'probabilities': array([0.4366051 , 0.56339484], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.0396518], dtype=float32),
#   'logistic': array([0.7387828], dtype=float32),
#   'probabilities': array([0.26121718, 0.73878276], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7190449], dtype=float32),
#   'logistic': array([0.1519942], dtype=float32),
#   'probabilities': array([0.8480058 , 0.15199421], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.21677983], dtype=float32),
#   'logistic': array([0.5539837], dtype=float32),
#   'probabilities': array([0.44601628, 0.5539837 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.3953676], dtype=float32),
#   'logistic': array([0.08352664], dtype=float32),
#   'probabilities': array([0.9164733 , 0.08352662], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8911417], dtype=float32),
#   'logistic': array([0.1311143], dtype=float32),
#   'probabilities': array([0.86888564, 0.13111435], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.39426672], dtype=float32),
#   'logistic': array([0.5973094], dtype=float32),
#   'probabilities': array([0.4026906, 0.5973094], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.84156024], dtype=float32),
#   'logistic': array([0.3012063], dtype=float32),
#   'probabilities': array([0.69879377, 0.30120632], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.861393], dtype=float32),
#   'logistic': array([0.1345408], dtype=float32),
#   'probabilities': array([0.8654592 , 0.13454077], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.05582201], dtype=float32),
#   'logistic': array([0.48604813], dtype=float32),
#   'probabilities': array([0.5139519 , 0.48604813], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.8508012], dtype=float32),
#   'logistic': array([0.13577884], dtype=float32),
#   'probabilities': array([0.8642212 , 0.13577886], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.86930573], dtype=float32),
#   'logistic': array([0.2953988], dtype=float32),
#   'probabilities': array([0.7046012 , 0.29539877], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.08980846], dtype=float32),
#   'logistic': array([0.52243704], dtype=float32),
#   'probabilities': array([0.47756296, 0.52243704], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.4180229], dtype=float32),
#   'logistic': array([0.19497171], dtype=float32),
#   'probabilities': array([0.80502826, 0.19497171], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.23413289], dtype=float32),
#   'logistic': array([0.4417327], dtype=float32),
#   'probabilities': array([0.5582673, 0.4417327], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.37422], dtype=float32),
#   'logistic': array([0.5924783], dtype=float32),
#   'probabilities': array([0.4075217, 0.5924783], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8528787], dtype=float32),
#   'logistic': array([0.29882938], dtype=float32),
#   'probabilities': array([0.7011707 , 0.29882935], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.02073407], dtype=float32),
#   'logistic': array([0.49481666], dtype=float32),
#   'probabilities': array([0.50518334, 0.49481666], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.9203565], dtype=float32),
#   'logistic': array([0.1278218], dtype=float32),
#   'probabilities': array([0.8721782 , 0.12782182], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.35741848], dtype=float32),
#   'logistic': array([0.41158462], dtype=float32),
#   'probabilities': array([0.5884154 , 0.41158462], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.669533], dtype=float32),
#   'logistic': array([0.15848646], dtype=float32),
#   'probabilities': array([0.8415136 , 0.15848646], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.06283665], dtype=float32),
#   'logistic': array([0.515704], dtype=float32),
#   'probabilities': array([0.484296, 0.515704], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.34011], dtype=float32),
#   'logistic': array([0.20749196], dtype=float32),
#   'probabilities': array([0.792508  , 0.20749198], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6406934], dtype=float32),
#   'logistic': array([0.16237074], dtype=float32),
#   'probabilities': array([0.83762926, 0.16237073], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8903141], dtype=float32),
#   'logistic': array([0.291045], dtype=float32),
#   'probabilities': array([0.708955, 0.291045], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
# ...
#  {'logits': array([-1.6312454], dtype=float32),
#   'logistic': array([0.16365981], dtype=float32),
#   'probabilities': array([0.8363401 , 0.16365981], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([1.7034961], dtype=float32),
#   'logistic': array([0.8459908], dtype=float32),
#   'probabilities': array([0.15400922, 0.84599084], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7592554], dtype=float32),
#   'logistic': array([0.1468836], dtype=float32),
#   'probabilities': array([0.8531164 , 0.14688362], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5398092], dtype=float32),
#   'logistic': array([0.176563], dtype=float32),
#   'probabilities': array([0.823437  , 0.17656301], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6912819], dtype=float32),
#   'logistic': array([0.33374798], dtype=float32),
#   'probabilities': array([0.666252  , 0.33374798], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.28317684], dtype=float32),
#   'logistic': array([0.4296751], dtype=float32),
#   'probabilities': array([0.5703249, 0.4296751], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.456888], dtype=float32),
#   'logistic': array([0.18894377], dtype=float32),
#   'probabilities': array([0.81105626, 0.18894377], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.2704215], dtype=float32),
#   'logistic': array([0.56719637], dtype=float32),
#   'probabilities': array([0.43280363, 0.56719637], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.3774214], dtype=float32),
#   'logistic': array([0.08491069], dtype=float32),
#   'probabilities': array([0.9150893 , 0.08491071], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3253763], dtype=float32),
#   'logistic': array([0.2099252], dtype=float32),
#   'probabilities': array([0.79007477, 0.2099252 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.22353268], dtype=float32),
#   'logistic': array([0.5556516], dtype=float32),
#   'probabilities': array([0.44434834, 0.5556516 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.25514078], dtype=float32),
#   'logistic': array([0.5634414], dtype=float32),
#   'probabilities': array([0.43655854, 0.5634414 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.15862167], dtype=float32),
#   'logistic': array([0.46042752], dtype=float32),
#   'probabilities': array([0.5395725, 0.4604275], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.2425698], dtype=float32),
#   'logistic': array([0.43965316], dtype=float32),
#   'probabilities': array([0.56034684, 0.43965316], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.02170885], dtype=float32),
#   'logistic': array([0.505427], dtype=float32),
#   'probabilities': array([0.494573, 0.505427], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.26256865], dtype=float32),
#   'logistic': array([0.43473238], dtype=float32),
#   'probabilities': array([0.5652676 , 0.43473238], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0125633], dtype=float32),
#   'logistic': array([0.26647848], dtype=float32),
#   'probabilities': array([0.7335215, 0.2664785], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2250084], dtype=float32),
#   'logistic': array([0.2270563], dtype=float32),
#   'probabilities': array([0.7729437 , 0.22705625], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.8550575], dtype=float32),
#   'logistic': array([0.298373], dtype=float32),
#   'probabilities': array([0.70162696, 0.298373  ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.9073738], dtype=float32),
#   'logistic': array([0.7124624], dtype=float32),
#   'probabilities': array([0.28753754, 0.7124625 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.42267543], dtype=float32),
#   'logistic': array([0.39587674], dtype=float32),
#   'probabilities': array([0.6041233 , 0.39587674], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7935107], dtype=float32),
#   'logistic': array([0.14264283], dtype=float32),
#   'probabilities': array([0.85735714, 0.14264284], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.91515154], dtype=float32),
#   'logistic': array([0.28594685], dtype=float32),
#   'probabilities': array([0.71405315, 0.28594685], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.14119387], dtype=float32),
#   'logistic': array([0.46476007], dtype=float32),
#   'probabilities': array([0.53523993, 0.46476004], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.19626439], dtype=float32),
#   'logistic': array([0.4510908], dtype=float32),
#   'probabilities': array([0.5489092 , 0.45109078], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6315454], dtype=float32),
#   'logistic': array([0.16361877], dtype=float32),
#   'probabilities': array([0.83638126, 0.16361877], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6111732], dtype=float32),
#   'logistic': array([0.1664258], dtype=float32),
#   'probabilities': array([0.8335742, 0.1664258], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.0610223], dtype=float32),
#   'logistic': array([0.25711414], dtype=float32),
#   'probabilities': array([0.7428859 , 0.25711417], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.19800222], dtype=float32),
#   'logistic': array([0.45066053], dtype=float32),
#   'probabilities': array([0.5493395 , 0.45066056], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.79013014], dtype=float32),
#   'logistic': array([0.6878593], dtype=float32),
#   'probabilities': array([0.3121407 , 0.68785924], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.5605123], dtype=float32),
#   'logistic': array([0.17357314], dtype=float32),
#   'probabilities': array([0.82642686, 0.17357315], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.35586798], dtype=float32),
#   'logistic': array([0.41196018], dtype=float32),
#   'probabilities': array([0.5880398 , 0.41196018], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7811419], dtype=float32),
#   'logistic': array([0.14416215], dtype=float32),
#   'probabilities': array([0.8558378, 0.1441622], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-2.1451764], dtype=float32),
#   'logistic': array([0.10478279], dtype=float32),
#   'probabilities': array([0.8952171 , 0.10478282], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.3286108], dtype=float32),
#   'logistic': array([0.20938927], dtype=float32),
#   'probabilities': array([0.7906108 , 0.20938925], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.4824891], dtype=float32),
#   'logistic': array([0.6183355], dtype=float32),
#   'probabilities': array([0.38166454, 0.6183355 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.4324435], dtype=float32),
#   'logistic': array([0.606457], dtype=float32),
#   'probabilities': array([0.39354298, 0.606457  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.399051], dtype=float32),
#   'logistic': array([0.40154037], dtype=float32),
#   'probabilities': array([0.5984596 , 0.40154037], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.2252911], dtype=float32),
#   'logistic': array([0.22700667], dtype=float32),
#   'probabilities': array([0.7729933 , 0.22700666], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.07984912], dtype=float32),
#   'logistic': array([0.48004833], dtype=float32),
#   'probabilities': array([0.51995164, 0.48004827], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([2.1545033], dtype=float32),
#   'logistic': array([0.89608884], dtype=float32),
#   'probabilities': array([0.10391116, 0.8960889 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.2547387], dtype=float32),
#   'logistic': array([0.4366575], dtype=float32),
#   'probabilities': array([0.5633425, 0.4366575], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6753268], dtype=float32),
#   'logistic': array([0.3373051], dtype=float32),
#   'probabilities': array([0.6626949, 0.3373051], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([0.2281686], dtype=float32),
#   'logistic': array([0.55679595], dtype=float32),
#   'probabilities': array([0.44320405, 0.55679595], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.6371874], dtype=float32),
#   'logistic': array([0.16284814], dtype=float32),
#   'probabilities': array([0.8371518 , 0.16284813], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7467468], dtype=float32),
#   'logistic': array([0.14845797], dtype=float32),
#   'probabilities': array([0.85154194, 0.14845799], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-1.7867541], dtype=float32),
#   'logistic': array([0.14347112], dtype=float32),
#   'probabilities': array([0.8565289 , 0.14347114], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)},
#  {'logits': array([-0.6417386], dtype=float32),
#   'logistic': array([0.34485364], dtype=float32),
#   'probabilities': array([0.65514636, 0.34485364], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'all_class_ids': array([0, 1]),
#   'all_classes': array([b'0', b'1'], dtype=object)}]

# %%
eval_input_func = tf.compat.v1.estimator.inputs.pandas_input_fn(x=x_test, y=y_test,batch_size=10, num_epochs=1, shuffle=False)
results=model.evaluate(eval_input_func)
results
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-01-13T09:47:06Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\jagumiel\AppData\Local\Temp\tmp9nr2npm1\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.51762s
# INFO:tensorflow:Finished evaluation at 2021-01-13-09:47:06
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.73023254, accuracy_baseline = 0.66511625, auc = 0.7735528, auc_precision_recall = 0.5976133, average_loss = 0.5380436, global_step = 1000, label/mean = 0.33488372, loss = 0.53659576, precision = 0.64, prediction/mean = 0.33980405, recall = 0.44444445
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: C:\Users\jagumiel\AppData\Local\Temp\tmp9nr2npm1\model.ckpt-1000
# {'accuracy': 0.73023254,
#  'accuracy_baseline': 0.66511625,
#  'auc': 0.7735528,
#  'auc_precision_recall': 0.5976133,
#  'average_loss': 0.5380436,
#  'label/mean': 0.33488372,
#  'loss': 0.53659576,
#  'precision': 0.64,
#  'prediction/mean': 0.33980405,
#  'recall': 0.44444445,
#  'global_step': 1000}

# %%
x_data_test = diabetes_test.drop('Class',axis=1)
labels_test = diabetes_test['Class']
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_data_train,labels_train,test_size=0.75,random_state=101)


eval_input_func = tf.compat.v1.estimator.inputs.pandas_input_fn(x=x_test, y=y_test,batch_size=10, num_epochs=1, shuffle=False)
results=model.evaluate(eval_input_func)
results
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Layer linear/linear_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-01-13T09:47:17Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\jagumiel\AppData\Local\Temp\tmp9nr2npm1\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.58653s
# INFO:tensorflow:Finished evaluation at 2021-01-13-09:47:17
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.7602459, accuracy_baseline = 0.6577869, auc = 0.7961647, auc_precision_recall = 0.6653, average_loss = 0.52358043, global_step = 1000, label/mean = 0.34221312, loss = 0.5233023, precision = 0.72321427, prediction/mean = 0.3392083, recall = 0.48502994
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: C:\Users\jagumiel\AppData\Local\Temp\tmp9nr2npm1\model.ckpt-1000
# {'accuracy': 0.7602459,
#  'accuracy_baseline': 0.6577869,
#  'auc': 0.7961647,
#  'auc_precision_recall': 0.6653,
#  'average_loss': 0.52358043,
#  'label/mean': 0.34221312,
#  'loss': 0.5233023,
#  'precision': 0.72321427,
#  'prediction/mean': 0.3392083,
#  'recall': 0.48502994,
#  'global_step': 1000}
